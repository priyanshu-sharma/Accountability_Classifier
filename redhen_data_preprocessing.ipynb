# %% [markdown]
# # REDHEN DATA

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import pickle
from fastai.nlp import *
from sklearn.linear_model import LogisticRegression

# %%
data = pd.read_excel('/home/spriyanshu723/Isla Vista - All Excerpts - 1_2_2019.xlsx')
data.head()
# Out:
#   StoryID                                            Excerpt  \
# 0  NI2599  Are guns the problem, video\ngames, the increa...
# 1  NI2599  May 23, 2014, in Isla Vista, California. 22-ye...
# 2  NI2951  A 22-year-old student last Friday killed six p...
# 3  NI2951  A 22-year-old student last Friday killed six p...
# 4  NI2951  Elliot Rodger was not a typical man � few of u...
#
#                                CodesApplied_Combined  ACCOUNT  \
# 0  ACCOUNTABILITY, ACCOUNT- Culture/societal risk...        1
# 1                    EVENT, TRAUMA, TRAUMA- Physical        0
# 2                                              EVENT        0
# 3  ACCOUNTABILITY, ACCOUNT- Culture/societal risk...        1
# 4  PERPETRATOR, ACCOUNTABILITY, ACCOUNT- Individu...        1
#
#    ACCOUNT_Cultural  ACCOUNT_Individual  ACCOUNT_Other  COMMUNITYRECOVERY  \
# 0                 1                   0              0                 99
# 1                 0                   0              0                 99
# 2                 0                   0              0                 99
# 3                 1                   0              0                 99
# 4                 0                   1              0                 99
#
#    EVENT  GRIEF  ...  SOCIALSUPPORT  THREAT  THREAT_Assessment  TRAUMA  \
# 0      0      0  ...              0       0                 99       0
# 1      1      0  ...              0       0                 99       1
# 2      1      0  ...              0       0                 99       0
# 3      0      0  ...              0       0                 99       0
# 4      0      0  ...              0       0                 99       0
#
#    TRAUMA_Physical  TRAUMA_Psychological  TRAUMA_Individual  TRAUMA_Community  \
# 0                0                     0                 99                99
# 1                1                     0                 99                99
# 2                0                     0                 99                99
# 3                0                     0                 99                99
# 4                0                     0                 99                99
#
#    TRAUMA_Societal  VICTIMS
# 0               99        0
# 1               99        0
# 2               99        0
# 3               99        0
# 4               99        0
#
# [5 rows x 53 columns]

# %%
data.columns
# Out:
# Index(['StoryID', 'Excerpt', 'CodesApplied_Combined', 'ACCOUNT',
#        'ACCOUNT_Cultural', 'ACCOUNT_Individual', 'ACCOUNT_Other',
#        'COMMUNITYRECOVERY', 'EVENT', 'GRIEF', 'GRIEF_Individual',
#        'GRIEF_Community', 'GRIEF_Societal', 'HERO', 'INVESTIGATION', 'JOURNEY',
#        'JOURNEY_Mental', 'JOURNEY_Physical', 'LEGAL', 'MEDIA', 'MISCELLANEOUS',
#        'MOURNING', 'MOURNING_Individual', 'MOURNING_Community',
#        'MOURNING_Societal', 'PERPETRATOR', 'PHOTO', 'POLICY', 'POLICY_Guns',
#        'POLICY_InfoSharing', 'POLICY_MentalHealth', 'POLICY_Other',
#        'POLICY_VictimAdv', 'POLICY_OtherAdv', 'POLICY_Practice',
#        'PRIVATESECTOR', 'RACECULTURE', 'RESOURCES', 'SAFETY',
#        'SAFETY_Community', 'SAFETY_Individual', 'SAFETY_SchoolOrg',
#        'SAFETY_Societal', 'SOCIALSUPPORT', 'THREAT', 'THREAT_Assessment',
#        'TRAUMA', 'TRAUMA_Physical', 'TRAUMA_Psychological',
#        'TRAUMA_Individual', 'TRAUMA_Community', 'TRAUMA_Societal', 'VICTIMS'],
#       dtype='object')

# %%
data.shape
# Out:
# (8131, 53)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8131 entries, 0 to 8130
# Data columns (total 53 columns):
# StoryID                  8131 non-null object
# Excerpt                  8130 non-null object
# CodesApplied_Combined    8128 non-null object
# ACCOUNT                  8131 non-null int64
# ACCOUNT_Cultural         8131 non-null int64
# ACCOUNT_Individual       8131 non-null int64
# ACCOUNT_Other            8131 non-null int64
# COMMUNITYRECOVERY        8131 non-null int64
# EVENT                    8131 non-null int64
# GRIEF                    8131 non-null int64
# GRIEF_Individual         8131 non-null int64
# GRIEF_Community          8131 non-null int64
# GRIEF_Societal           8131 non-null int64
# HERO                     8131 non-null int64
# INVESTIGATION            8131 non-null int64
# JOURNEY                  8131 non-null int64
# JOURNEY_Mental           8131 non-null int64
# JOURNEY_Physical         8131 non-null int64
# LEGAL                    8131 non-null int64
# MEDIA                    8131 non-null int64
# MISCELLANEOUS            8131 non-null int64
# MOURNING                 8131 non-null int64
# MOURNING_Individual      8131 non-null int64
# MOURNING_Community       8131 non-null int64
# MOURNING_Societal        8131 non-null int64
# PERPETRATOR              8131 non-null int64
# PHOTO                    8131 non-null int64
# POLICY                   8131 non-null int64
# POLICY_Guns              8131 non-null int64
# POLICY_InfoSharing       8131 non-null int64
# POLICY_MentalHealth      8131 non-null int64
# POLICY_Other             8131 non-null int64
# POLICY_VictimAdv         8131 non-null int64
# POLICY_OtherAdv          8131 non-null int64
# POLICY_Practice          8131 non-null int64
# PRIVATESECTOR            8131 non-null int64
# RACECULTURE              8131 non-null int64
# RESOURCES                8131 non-null int64
# SAFETY                   8131 non-null int64
# SAFETY_Community         8131 non-null int64
# SAFETY_Individual        8131 non-null int64
# SAFETY_SchoolOrg         8131 non-null int64
# SAFETY_Societal          8131 non-null int64
# SOCIALSUPPORT            8131 non-null int64
# THREAT                   8131 non-null int64
# THREAT_Assessment        8131 non-null int64
# TRAUMA                   8131 non-null int64
# TRAUMA_Physical          8131 non-null int64
# TRAUMA_Psychological     8131 non-null int64
# TRAUMA_Individual        8131 non-null int64
# TRAUMA_Community         8131 non-null int64
# TRAUMA_Societal          8131 non-null int64
# VICTIMS                  8131 non-null int64
# dtypes: int64(50), object(3)
# memory usage: 3.3+ MB

# %% [markdown]
# ## DATA ANALYSIS

# %% [markdown]
# ### NUMBER OF WORDS CALCULATION

# %%
data['word_count'] = data['Excerpt'].apply(lambda x: len(str(x).split(" ")))
data[['Excerpt','word_count']].head()
# Out:
#                                              Excerpt  word_count
# 0  Are guns the problem, video\ngames, the increa...          50
# 1  May 23, 2014, in Isla Vista, California. 22-ye...         138
# 2  A 22-year-old student last Friday killed six p...          22
# 3  A 22-year-old student last Friday killed six p...          57
# 4  Elliot Rodger was not a typical man � few of u...          44

# %% [markdown]
# ### NUMBER OF CHARACTER CALCULATION

# %%
data['char_count'] = data['Excerpt'].str.len() ## this also includes spaces
data[['Excerpt','char_count']].head()
# Out:
#                                              Excerpt  char_count
# 0  Are guns the problem, video\ngames, the increa...       279.0
# 1  May 23, 2014, in Isla Vista, California. 22-ye...       848.0
# 2  A 22-year-old student last Friday killed six p...       121.0
# 3  A 22-year-old student last Friday killed six p...       358.0
# 4  Elliot Rodger was not a typical man � few of u...       238.0

# %% [markdown]
# ## BASIC PRE-PROCESSING

# %% [markdown]
# ### REMOVING PUNCTUATION

# %%
data['Excerpt'] = data['Excerpt'].str.replace('[^\w\s]','')
data['Excerpt'].head()
# Out:
# 0    Are guns the problem video\ngames the increase...
# 1    May 23 2014 in Isla Vista California 22yearold...
# 2    A 22yearold student last Friday killed six peo...
# 3    A 22yearold student last Friday killed six peo...
# 4    Elliot Rodger was not a typical man  few of us...
# Name: Excerpt, dtype: object

# %% [markdown]
# ### SPELLING CORRECTION

# %%
from textblob import TextBlob
data['Excerpt'][:5].apply(lambda x: str(TextBlob(x).correct()))
# Out:
# 0    Are guns the problem video\ngames the increase...
# 1    May 23 2014 in Sea Vista California 22yearold ...
# 2    A 22yearold student last Friday killed six peo...
# 3    A 22yearold student last Friday killed six peo...
# 4    Allot Lodger was not a typical man  few of us ...
# Name: Excerpt, dtype: object

# %% [markdown]
# ### PREPROCESSING

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/spriyanshu723/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stopword = nltk.corpus.stopwords.words('english')

# %%
#stop_words = stopwords.words("english")
#stemmer = SnowballStemmer("english")
ps = nltk.PorterStemmer()
stop_words = stopword
stemmer = ps

# %%
TEXT_CLEANING_RE = "@\S+|https?:\S+|http?:\S|[^A-Za-z0-9]+"

# %%
def preprocess(text, stem=False):
    # Remove link,user and special characters
    text = re.sub(TEXT_CLEANING_RE, ' ', str(text).lower()).strip()
    tokens = []
    for token in text.split():
        if token not in stop_words:
            if stem:
                tokens.append(stemmer.stem(token))
            else:
                tokens.append(token)
    return " ".join(tokens)

# %%
data['Excerpt_pre'] = data['Excerpt'].apply(lambda x: preprocess(x))
data.head()
# Out:
#      StoryID                                            Excerpt  \
# 7992  NI3079  Elliot Rodger Wangs roommate stabbed Wang and ...
# 4686  NI2689  Because the tragedy unfolded at the start of a...
# 6130  NI2400  Gunrelated restraining orders Also passed in r...
# 5876  NI1393  Linder said she will also remember Weiss for h...
# 4126  NI3259  I mean I know how this goes We all do Werent y...
#
#                                   CodesApplied_Combined  ACCOUNT  \
# 7992                                              EVENT        0
# 4686                                          RESOURCES        0
# 6130        POLICY, POLICY- Guns, POLICY- Mental health        0
# 5876                                VICTIMS, GRIEF/LOSS        0
# 4126  ACCOUNTABILITY, ACCOUNT- Culture/societal risk...        1
#
#       ACCOUNT_Cultural  ACCOUNT_Individual  ACCOUNT_Other  COMMUNITYRECOVERY  \
# 7992                 0                   0              0                 99
# 4686                 0                   0              0                 99
# 6130                 0                   0              0                 99
# 5876                 0                   0              0                 99
# 4126                 1                   0              0                 99
#
#       EVENT  GRIEF  ...  TRAUMA  TRAUMA_Physical  TRAUMA_Psychological  \
# 7992      1      0  ...       0                0                     0
# 4686      0      0  ...       0                0                     0
# 6130      0      0  ...       0                0                     0
# 5876      0      1  ...       0                0                     0
# 4126      0      0  ...       0                0                     0
#
#       TRAUMA_Individual  TRAUMA_Community  TRAUMA_Societal  VICTIMS  \
# 7992                 99                99               99        0
# 4686                 99                99               99        0
# 6130                 99                99               99        0
# 5876                 99                99               99        1
# 4126                 99                99               99        0
#
#       word_count  char_count  \
# 7992          34       215.0
# 4686          32       228.0
# 6130         122       734.0
# 5876         100       499.0
# 4126          85       425.0
#
#                                             Excerpt_pre
# 7992  elliot rodger wangs roommate stabbed wang two ...
# 4686  tragedy unfolded start holiday weekend school ...
# 6130  gunrelated restraining orders also passed resp...
# 5876  linder said also remember weiss epic shot pool...
# 4126  mean know goes werent sort expecting father on...
#
# [5 rows x 56 columns]

# %% [markdown]
# ### TOKENIZATION

# %%
def tokenization(text):
    text = re.split('\W+', text)
    return text

# %%
data['Excerpt_tokenized'] = data['Excerpt_pre'].apply(lambda x: tokenization(x.lower()))
data.head()
# Out:
#      StoryID                                            Excerpt  \
# 7992  NI3079  Elliot Rodger Wangs roommate stabbed Wang and ...
# 4686  NI2689  Because the tragedy unfolded at the start of a...
# 6130  NI2400  Gunrelated restraining orders Also passed in r...
# 5876  NI1393  Linder said she will also remember Weiss for h...
# 4126  NI3259  I mean I know how this goes We all do Werent y...
#
#                                   CodesApplied_Combined  ACCOUNT  \
# 7992                                              EVENT        0
# 4686                                          RESOURCES        0
# 6130        POLICY, POLICY- Guns, POLICY- Mental health        0
# 5876                                VICTIMS, GRIEF/LOSS        0
# 4126  ACCOUNTABILITY, ACCOUNT- Culture/societal risk...        1
#
#       ACCOUNT_Cultural  ACCOUNT_Individual  ACCOUNT_Other  COMMUNITYRECOVERY  \
# 7992                 0                   0              0                 99
# 4686                 0                   0              0                 99
# 6130                 0                   0              0                 99
# 5876                 0                   0              0                 99
# 4126                 1                   0              0                 99
#
#       EVENT  GRIEF  ...  TRAUMA_Physical  TRAUMA_Psychological  \
# 7992      1      0  ...                0                     0
# 4686      0      0  ...                0                     0
# 6130      0      0  ...                0                     0
# 5876      0      1  ...                0                     0
# 4126      0      0  ...                0                     0
#
#       TRAUMA_Individual  TRAUMA_Community  TRAUMA_Societal  VICTIMS  \
# 7992                 99                99               99        0
# 4686                 99                99               99        0
# 6130                 99                99               99        0
# 5876                 99                99               99        1
# 4126                 99                99               99        0
#
#       word_count  char_count  \
# 7992          34       215.0
# 4686          32       228.0
# 6130         122       734.0
# 5876         100       499.0
# 4126          85       425.0
#
#                                             Excerpt_pre  \
# 7992  elliot rodger wangs roommate stabbed wang two ...
# 4686  tragedy unfolded start holiday weekend school ...
# 6130  gunrelated restraining orders also passed resp...
# 5876  linder said also remember weiss epic shot pool...
# 4126  mean know goes werent sort expecting father on...
#
#                                       Excerpt_tokenized
# 7992  [elliot, rodger, wangs, roommate, stabbed, wan...
# 4686  [tragedy, unfolded, start, holiday, weekend, s...
# 6130  [gunrelated, restraining, orders, also, passed...
# 5876  [linder, said, also, remember, weiss, epic, sh...
# 4126  [mean, know, goes, werent, sort, expecting, fa...
#
# [5 rows x 57 columns]

# %% [markdown]
# ### STOP WORDS REMOVAL

# %%
stopword = nltk.corpus.stopwords.words('english')

# %%
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text

# %%
data['Excerpt_nonstop'] = data['Excerpt_tokenized'].apply(lambda x: remove_stopwords(x))
data.head()
# Out:
#      StoryID                                            Excerpt  \
# 7992  NI3079  Elliot Rodger Wangs roommate stabbed Wang and ...
# 4686  NI2689  Because the tragedy unfolded at the start of a...
# 6130  NI2400  Gunrelated restraining orders Also passed in r...
# 5876  NI1393  Linder said she will also remember Weiss for h...
# 4126  NI3259  I mean I know how this goes We all do Werent y...
#
#                                   CodesApplied_Combined  ACCOUNT  \
# 7992                                              EVENT        0
# 4686                                          RESOURCES        0
# 6130        POLICY, POLICY- Guns, POLICY- Mental health        0
# 5876                                VICTIMS, GRIEF/LOSS        0
# 4126  ACCOUNTABILITY, ACCOUNT- Culture/societal risk...        1
#
#       ACCOUNT_Cultural  ACCOUNT_Individual  ACCOUNT_Other  COMMUNITYRECOVERY  \
# 7992                 0                   0              0                 99
# 4686                 0                   0              0                 99
# 6130                 0                   0              0                 99
# 5876                 0                   0              0                 99
# 4126                 1                   0              0                 99
#
#       EVENT  GRIEF  ...  TRAUMA_Psychological  TRAUMA_Individual  \
# 7992      1      0  ...                     0                 99
# 4686      0      0  ...                     0                 99
# 6130      0      0  ...                     0                 99
# 5876      0      1  ...                     0                 99
# 4126      0      0  ...                     0                 99
#
#       TRAUMA_Community  TRAUMA_Societal  VICTIMS  word_count  char_count  \
# 7992                99               99        0          34       215.0
# 4686                99               99        0          32       228.0
# 6130                99               99        0         122       734.0
# 5876                99               99        1         100       499.0
# 4126                99               99        0          85       425.0
#
#                                             Excerpt_pre  \
# 7992  elliot rodger wangs roommate stabbed wang two ...
# 4686  tragedy unfolded start holiday weekend school ...
# 6130  gunrelated restraining orders also passed resp...
# 5876  linder said also remember weiss epic shot pool...
# 4126  mean know goes werent sort expecting father on...
#
#                                       Excerpt_tokenized  \
# 7992  [elliot, rodger, wangs, roommate, stabbed, wan...
# 4686  [tragedy, unfolded, start, holiday, weekend, s...
# 6130  [gunrelated, restraining, orders, also, passed...
# 5876  [linder, said, also, remember, weiss, epic, sh...
# 4126  [mean, know, goes, werent, sort, expecting, fa...
#
#                                         Excerpt_nonstop
# 7992  [elliot, rodger, wangs, roommate, stabbed, wan...
# 4686  [tragedy, unfolded, start, holiday, weekend, s...
# 6130  [gunrelated, restraining, orders, also, passed...
# 5876  [linder, said, also, remember, weiss, epic, sh...
# 4126  [mean, know, goes, werent, sort, expecting, fa...
#
# [5 rows x 58 columns]

# %% [markdown]
# ### STEMMING

# %%
ps = nltk.PorterStemmer()

# %%
def stemming(text):
    text = [ps.stem(word) for word in text]
    return text

# %%
import sys
sys.setrecursionlimit(15000)

# %%
data['Excerpt_stemmed'] = data['Excerpt_nonstop'].apply(lambda x: stemming(x))
data.head()
# Out:
#      StoryID                                            Excerpt  \
# 7992  NI3079  Elliot Rodger Wangs roommate stabbed Wang and ...
# 4686  NI2689  Because the tragedy unfolded at the start of a...
# 6130  NI2400  Gunrelated restraining orders Also passed in r...
# 5876  NI1393  Linder said she will also remember Weiss for h...
# 4126  NI3259  I mean I know how this goes We all do Werent y...
#
#                                   CodesApplied_Combined  ACCOUNT  \
# 7992                                              EVENT        0
# 4686                                          RESOURCES        0
# 6130        POLICY, POLICY- Guns, POLICY- Mental health        0
# 5876                                VICTIMS, GRIEF/LOSS        0
# 4126  ACCOUNTABILITY, ACCOUNT- Culture/societal risk...        1
#
#       ACCOUNT_Cultural  ACCOUNT_Individual  ACCOUNT_Other  COMMUNITYRECOVERY  \
# 7992                 0                   0              0                 99
# 4686                 0                   0              0                 99
# 6130                 0                   0              0                 99
# 5876                 0                   0              0                 99
# 4126                 1                   0              0                 99
#
#       EVENT  GRIEF  ...  TRAUMA_Individual  TRAUMA_Community  TRAUMA_Societal  \
# 7992      1      0  ...                 99                99               99
# 4686      0      0  ...                 99                99               99
# 6130      0      0  ...                 99                99               99
# 5876      0      1  ...                 99                99               99
# 4126      0      0  ...                 99                99               99
#
#       VICTIMS  word_count  char_count  \
# 7992        0          34       215.0
# 4686        0          32       228.0
# 6130        0         122       734.0
# 5876        1         100       499.0
# 4126        0          85       425.0
#
#                                             Excerpt_pre  \
# 7992  elliot rodger wangs roommate stabbed wang two ...
# 4686  tragedy unfolded start holiday weekend school ...
# 6130  gunrelated restraining orders also passed resp...
# 5876  linder said also remember weiss epic shot pool...
# 4126  mean know goes werent sort expecting father on...
#
#                                       Excerpt_tokenized  \
# 7992  [elliot, rodger, wangs, roommate, stabbed, wan...
# 4686  [tragedy, unfolded, start, holiday, weekend, s...
# 6130  [gunrelated, restraining, orders, also, passed...
# 5876  [linder, said, also, remember, weiss, epic, sh...
# 4126  [mean, know, goes, werent, sort, expecting, fa...
#
#                                         Excerpt_nonstop  \
# 7992  [elliot, rodger, wangs, roommate, stabbed, wan...
# 4686  [tragedy, unfolded, start, holiday, weekend, s...
# 6130  [gunrelated, restraining, orders, also, passed...
# 5876  [linder, said, also, remember, weiss, epic, sh...
# 4126  [mean, know, goes, werent, sort, expecting, fa...
#
#                                         Excerpt_stemmed
# 7992  [elliot, rodger, wang, roommat, stab, wang, tw...
# 4686  [tragedi, unfold, start, holiday, weekend, sch...
# 6130  [gunrel, restrain, order, also, pass, respons,...
# 5876  [linder, said, also, rememb, weiss, epic, shot...
# 4126  [mean, know, goe, werent, sort, expect, father...
#
# [5 rows x 59 columns]

# %% [markdown]
# ###  LAMMITIZATION

# %%
wn = nltk.WordNetLemmatizer()

# %%
def lemmatizer(text):
    text = [wn.lemmatize(word) for word in text]
    return text

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/spriyanshu723/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
data['Excerpt_lemmatized'] = data['Excerpt_nonstop'].apply(lambda x: lemmatizer(x))
data.head()
# Out:
#      StoryID                                            Excerpt  \
# 7992  NI3079  Elliot Rodger Wangs roommate stabbed Wang and ...
# 4686  NI2689  Because the tragedy unfolded at the start of a...
# 6130  NI2400  Gunrelated restraining orders Also passed in r...
# 5876  NI1393  Linder said she will also remember Weiss for h...
# 4126  NI3259  I mean I know how this goes We all do Werent y...
#
#                                   CodesApplied_Combined  ACCOUNT  \
# 7992                                              EVENT        0
# 4686                                          RESOURCES        0
# 6130        POLICY, POLICY- Guns, POLICY- Mental health        0
# 5876                                VICTIMS, GRIEF/LOSS        0
# 4126  ACCOUNTABILITY, ACCOUNT- Culture/societal risk...        1
#
#       ACCOUNT_Cultural  ACCOUNT_Individual  ACCOUNT_Other  COMMUNITYRECOVERY  \
# 7992                 0                   0              0                 99
# 4686                 0                   0              0                 99
# 6130                 0                   0              0                 99
# 5876                 0                   0              0                 99
# 4126                 1                   0              0                 99
#
#       EVENT  GRIEF  ...  TRAUMA_Community  TRAUMA_Societal  VICTIMS  \
# 7992      1      0  ...                99               99        0
# 4686      0      0  ...                99               99        0
# 6130      0      0  ...                99               99        0
# 5876      0      1  ...                99               99        1
# 4126      0      0  ...                99               99        0
#
#       word_count  char_count  \
# 7992          34       215.0
# 4686          32       228.0
# 6130         122       734.0
# 5876         100       499.0
# 4126          85       425.0
#
#                                             Excerpt_pre  \
# 7992  elliot rodger wangs roommate stabbed wang two ...
# 4686  tragedy unfolded start holiday weekend school ...
# 6130  gunrelated restraining orders also passed resp...
# 5876  linder said also remember weiss epic shot pool...
# 4126  mean know goes werent sort expecting father on...
#
#                                       Excerpt_tokenized  \
# 7992  [elliot, rodger, wangs, roommate, stabbed, wan...
# 4686  [tragedy, unfolded, start, holiday, weekend, s...
# 6130  [gunrelated, restraining, orders, also, passed...
# 5876  [linder, said, also, remember, weiss, epic, sh...
# 4126  [mean, know, goes, werent, sort, expecting, fa...
#
#                                         Excerpt_nonstop  \
# 7992  [elliot, rodger, wangs, roommate, stabbed, wan...
# 4686  [tragedy, unfolded, start, holiday, weekend, s...
# 6130  [gunrelated, restraining, orders, also, passed...
# 5876  [linder, said, also, remember, weiss, epic, sh...
# 4126  [mean, know, goes, werent, sort, expecting, fa...
#
#                                         Excerpt_stemmed  \
# 7992  [elliot, rodger, wang, roommat, stab, wang, tw...
# 4686  [tragedi, unfold, start, holiday, weekend, sch...
# 6130  [gunrel, restrain, order, also, pass, respons,...
# 5876  [linder, said, also, rememb, weiss, epic, shot...
# 4126  [mean, know, goe, werent, sort, expect, father...
#
#                                      Excerpt_lemmatized
# 7992  [elliot, rodger, wangs, roommate, stabbed, wan...
# 4686  [tragedy, unfolded, start, holiday, weekend, s...
# 6130  [gunrelated, restraining, order, also, passed,...
# 5876  [linder, said, also, remember, wei, epic, shot...
# 4126  [mean, know, go, werent, sort, expecting, fath...
#
# [5 rows x 60 columns]

# %% [markdown]
# ### CLEANING

# %%
def clean_text(text):
    text_lc = "".join([word.lower() for word in text if word not in string.punctuation]) # remove puntuation
    text_rc = re.sub('[0-9]+', '', text_lc)
    tokens = re.split('\W+', text_rc)    # tokenization
    text = [ps.stem(word) for word in tokens if word not in stopword]  # remove stopwords and stemming
    return text

# %%
data['Excerpt_clean'] = data['Excerpt_pre'].apply(lambda x: clean_text(x))
data.head()
# Out:
#      StoryID                                            Excerpt  \
# 7992  NI3079  Elliot Rodger Wangs roommate stabbed Wang and ...
# 4686  NI2689  Because the tragedy unfolded at the start of a...
# 6130  NI2400  Gunrelated restraining orders Also passed in r...
# 5876  NI1393  Linder said she will also remember Weiss for h...
# 4126  NI3259  I mean I know how this goes We all do Werent y...
#
#                                   CodesApplied_Combined  ACCOUNT  \
# 7992                                              EVENT        0
# 4686                                          RESOURCES        0
# 6130        POLICY, POLICY- Guns, POLICY- Mental health        0
# 5876                                VICTIMS, GRIEF/LOSS        0
# 4126  ACCOUNTABILITY, ACCOUNT- Culture/societal risk...        1
#
#       ACCOUNT_Cultural  ACCOUNT_Individual  ACCOUNT_Other  COMMUNITYRECOVERY  \
# 7992                 0                   0              0                 99
# 4686                 0                   0              0                 99
# 6130                 0                   0              0                 99
# 5876                 0                   0              0                 99
# 4126                 1                   0              0                 99
#
#       EVENT  GRIEF  ...  TRAUMA_Societal  VICTIMS  word_count  char_count  \
# 7992      1      0  ...               99        0          34       215.0
# 4686      0      0  ...               99        0          32       228.0
# 6130      0      0  ...               99        0         122       734.0
# 5876      0      1  ...               99        1         100       499.0
# 4126      0      0  ...               99        0          85       425.0
#
#                                             Excerpt_pre  \
# 7992  elliot rodger wangs roommate stabbed wang two ...
# 4686  tragedy unfolded start holiday weekend school ...
# 6130  gunrelated restraining orders also passed resp...
# 5876  linder said also remember weiss epic shot pool...
# 4126  mean know goes werent sort expecting father on...
#
#                                       Excerpt_tokenized  \
# 7992  [elliot, rodger, wangs, roommate, stabbed, wan...
# 4686  [tragedy, unfolded, start, holiday, weekend, s...
# 6130  [gunrelated, restraining, orders, also, passed...
# 5876  [linder, said, also, remember, weiss, epic, sh...
# 4126  [mean, know, goes, werent, sort, expecting, fa...
#
#                                         Excerpt_nonstop  \
# 7992  [elliot, rodger, wangs, roommate, stabbed, wan...
# 4686  [tragedy, unfolded, start, holiday, weekend, s...
# 6130  [gunrelated, restraining, orders, also, passed...
# 5876  [linder, said, also, remember, weiss, epic, sh...
# 4126  [mean, know, goes, werent, sort, expecting, fa...
#
#                                         Excerpt_stemmed  \
# 7992  [elliot, rodger, wang, roommat, stab, wang, tw...
# 4686  [tragedi, unfold, start, holiday, weekend, sch...
# 6130  [gunrel, restrain, order, also, pass, respons,...
# 5876  [linder, said, also, rememb, weiss, epic, shot...
# 4126  [mean, know, goe, werent, sort, expect, father...
#
#                                      Excerpt_lemmatized  \
# 7992  [elliot, rodger, wangs, roommate, stabbed, wan...
# 4686  [tragedy, unfolded, start, holiday, weekend, s...
# 6130  [gunrelated, restraining, order, also, passed,...
# 5876  [linder, said, also, remember, wei, epic, shot...
# 4126  [mean, know, go, werent, sort, expecting, fath...
#
#                                           Excerpt_clean
# 7992  [elliot, rodger, wang, roommat, stab, wang, tw...
# 4686  [tragedi, unfold, start, holiday, weekend, sch...
# 6130  [gunrel, restrain, order, also, pass, respons,...
# 5876  [linder, said, also, rememb, weiss, epic, shot...
# 4126  [mean, know, goe, werent, sort, expect, father...
#
# [5 rows x 61 columns]

# %%
data.columns
# Out:
# Index(['StoryID', 'Excerpt', 'CodesApplied_Combined', 'ACCOUNT',
#        'ACCOUNT_Cultural', 'ACCOUNT_Individual', 'ACCOUNT_Other',
#        'COMMUNITYRECOVERY', 'EVENT', 'GRIEF', 'GRIEF_Individual',
#        'GRIEF_Community', 'GRIEF_Societal', 'HERO', 'INVESTIGATION', 'JOURNEY',
#        'JOURNEY_Mental', 'JOURNEY_Physical', 'LEGAL', 'MEDIA', 'MISCELLANEOUS',
#        'MOURNING', 'MOURNING_Individual', 'MOURNING_Community',
#        'MOURNING_Societal', 'PERPETRATOR', 'PHOTO', 'POLICY', 'POLICY_Guns',
#        'POLICY_InfoSharing', 'POLICY_MentalHealth', 'POLICY_Other',
#        'POLICY_VictimAdv', 'POLICY_OtherAdv', 'POLICY_Practice',
#        'PRIVATESECTOR', 'RACECULTURE', 'RESOURCES', 'SAFETY',
#        'SAFETY_Community', 'SAFETY_Individual', 'SAFETY_SchoolOrg',
#        'SAFETY_Societal', 'SOCIALSUPPORT', 'THREAT', 'THREAT_Assessment',
#        'TRAUMA', 'TRAUMA_Physical', 'TRAUMA_Psychological',
#        'TRAUMA_Individual', 'TRAUMA_Community', 'TRAUMA_Societal', 'VICTIMS',
#        'word_count', 'char_count', 'Excerpt_pre', 'Excerpt_tokenized',
#        'Excerpt_nonstop', 'Excerpt_stemmed', 'Excerpt_lemmatized',
#        'Excerpt_clean'],
#       dtype='object')

# %%
data.to_csv('redhen_preprocessed.csv')
